# %%
df = spark.read.table("default.taxi_silver")

print("Total rows:", df.count())
display(df.limit(5))
# Out:
# Total rows: 10000
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_datetime</th><th>dropoff_datetime</th><th>passenger_count</th><th>fare_amount</th><th>trip_distance_km</th><th>trip_duration_min</th><th>surge_multiplier</th><th>hour</th><th>dayofweek</th><th>month</th><th>year</th><th>pickup_zone</th><th>dropoff_zone</th></tr></thead><tbody><tr><td>2025-10-04 06:01:44</td><td>2025-10-04 06:27:03</td><td>1</td><td>248.96</td><td>10.732</td><td>25.32</td><td>1.0</td><td>6</td><td>7</td><td>10</td><td>2025</td><td>Rajajinagar</td><td>Koramangala</td></tr><tr><td>2025-10-09 11:00:38</td><td>2025-10-09 11:28:12</td><td>2</td><td>340.41</td><td>16.604</td><td>27.57</td><td>1.0</td><td>11</td><td>5</td><td>10</td><td>2025</td><td>Bannerghatta</td><td>Hebbal</td></tr><tr><td>2025-10-07 00:20:47</td><td>2025-10-07 00:33:47</td><td>2</td><td>200.3</td><td>8.718</td><td>13.01</td><td>1.0</td><td>0</td><td>3</td><td>10</td><td>2025</td><td>Yelahanka</td><td>Rajajinagar</td></tr><tr><td>2025-10-01 08:37:05</td><td>2025-10-01 08:44:57</td><td>2</td><td>95.69</td><td>2.259</td><td>7.87</td><td>1.0</td><td>8</td><td>4</td><td>10</td><td>2025</td><td>Whitefield</td><td>Whitefield</td></tr><tr><td>2025-10-01 03:37:41</td><td>2025-10-01 03:52:45</td><td>1</td><td>201.14</td><td>8.568</td><td>15.07</td><td>1.0</td><td>3</td><td>4</td><td>10</td><td>2025</td><td>MG_Road</td><td>Bannerghatta</td></tr></tbody></table></div>

# %%
feature_cols = [
    "trip_distance_km",
    "trip_duration_min",
    "hour",
    "dayofweek",
    "passenger_count"
]

label_col = "fare_amount"

df_model = df.select(feature_cols + [label_col])
display(df_model.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_distance_km</th><th>trip_duration_min</th><th>hour</th><th>dayofweek</th><th>passenger_count</th><th>fare_amount</th></tr></thead><tbody><tr><td>10.732</td><td>25.32</td><td>6</td><td>7</td><td>1</td><td>248.96</td></tr><tr><td>16.604</td><td>27.57</td><td>11</td><td>5</td><td>2</td><td>340.41</td></tr><tr><td>8.718</td><td>13.01</td><td>0</td><td>3</td><td>2</td><td>200.3</td></tr><tr><td>2.259</td><td>7.87</td><td>8</td><td>4</td><td>2</td><td>95.69</td></tr><tr><td>8.568</td><td>15.07</td><td>3</td><td>4</td><td>1</td><td>201.14</td></tr></tbody></table></div>

# %%
df_model = df_model.fillna({
    "passenger_count": 1
})

print("Rows after NA handling:", df_model.count())
# Out:
# Rows after NA handling: 10000

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

df_features = assembler.transform(df_model).select("features", label_col)
display(df_features.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>fare_amount</th></tr></thead><tbody><tr><td>Map(vectorType -> dense, length -> 5, values -> List(10.732, 25.32, 6.0, 7.0, 1.0))</td><td>248.96</td></tr><tr><td>Map(vectorType -> dense, length -> 5, values -> List(16.604, 27.57, 11.0, 5.0, 2.0))</td><td>340.41</td></tr><tr><td>Map(vectorType -> dense, length -> 5, values -> List(8.718, 13.01, 0.0, 3.0, 2.0))</td><td>200.3</td></tr><tr><td>Map(vectorType -> dense, length -> 5, values -> List(2.259, 7.87, 8.0, 4.0, 2.0))</td><td>95.69</td></tr><tr><td>Map(vectorType -> dense, length -> 5, values -> List(8.568, 15.07, 3.0, 4.0, 1.0))</td><td>201.14</td></tr></tbody></table></div>

# %%
train_df, test_df = df_features.randomSplit([0.8, 0.2], seed=42)

print("Train rows:", train_df.count())
print("Test rows :", test_df.count())
# Out:
# Train rows: 8079
# Test rows : 1921

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(
    featuresCol="features",
    labelCol="fare_amount"
)

lr_model = lr.fit(train_df)

# %%
predictions = lr_model.transform(test_df)
display(predictions.select("fare_amount", "prediction").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fare_amount</th><th>prediction</th></tr></thead><tbody><tr><td>72.97</td><td>58.1027556672542</td></tr><tr><td>58.08</td><td>60.74377692930943</td></tr><tr><td>60.32</td><td>62.88788067525049</td></tr><tr><td>57.61</td><td>59.275247565293135</td></tr><tr><td>62.38</td><td>64.62679244008339</td></tr><tr><td>69.13</td><td>60.72934899538718</td></tr><tr><td>57.77</td><td>60.25827979090727</td></tr><tr><td>59.3</td><td>61.77254575881866</td></tr><tr><td>78.06</td><td>62.9385604157286</td></tr><tr><td>58.72</td><td>61.656085493846504</td></tr></tbody></table></div>

# %%
from pyspark.ml.evaluation import RegressionEvaluator

rmse_eval = RegressionEvaluator(
    labelCol="fare_amount",
    predictionCol="prediction",
    metricName="rmse"
)

r2_eval = RegressionEvaluator(
    labelCol="fare_amount",
    predictionCol="prediction",
    metricName="r2"
)

rmse = rmse_eval.evaluate(predictions)
r2 = r2_eval.evaluate(predictions)

print(f"RMSE: {rmse}")
print(f"R²  : {r2}")
# Out:
# RMSE: 32.17587039073253
# R²  : 0.9421661963815748

# %%
MODEL_PATH = "dbfs:/models/taxi_fare_lr_v1"

lr_model.write().overwrite().save(MODEL_PATH)

print("✅ Model saved at:", MODEL_PATH)
# Out:
# ✅ Model saved at: dbfs:/models/taxi_fare_lr_v1

# %%
from pyspark.ml.regression import LinearRegressionModel

loaded_model = LinearRegressionModel.load(MODEL_PATH)

loaded_model.transform(test_df) \
    .select("fare_amount", "prediction") \
    .show(5)
# Out:
# +-----------+------------------+
# |fare_amount|        prediction|
# +-----------+------------------+
# |      72.97|  58.1027556672542|
# |      58.08| 60.74377692930943|
# |      60.32| 62.88788067525049|
# |      57.61|59.275247565293135|
# |      62.38| 64.62679244008339|
# +-----------+------------------+
# only showing top 5 rows
