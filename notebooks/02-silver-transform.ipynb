# %%
from pyspark.sql import functions as F

# Read Bronze table
bronze_df = spark.read.table("default.taxi_bronze")

print("Bronze row count:", bronze_df.count())
display(bronze_df.limit(5))
# Out:
# Bronze row count: 10000
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_datetime</th><th>dropoff_datetime</th><th>pickup_latitude</th><th>pickup_longitude</th><th>dropoff_latitude</th><th>dropoff_longitude</th><th>passenger_count</th><th>fare_amount</th><th>trip_distance_km</th><th>trip_duration_min</th><th>surge_multiplier</th><th>pickup_zone</th><th>dropoff_zone</th></tr></thead><tbody><tr><td>2025-10-04 06:01:44</td><td>2025-10-04 06:27:03</td><td>13.020352</td><td>77.557474</td><td>12.957031</td><td>77.632221</td><td>1</td><td>248.96</td><td>10.732</td><td>25.32</td><td>1.0</td><td>Rajajinagar</td><td>Koramangala</td></tr><tr><td>2025-10-09 11:00:38</td><td>2025-10-09 11:28:12</td><td>12.877326</td><td>77.572048</td><td>13.023753</td><td>77.602085</td><td>2</td><td>340.41</td><td>16.604</td><td>27.57</td><td>1.0</td><td>Bannerghatta</td><td>Hebbal</td></tr><tr><td>2025-10-07 00:20:47</td><td>2025-10-07 00:33:47</td><td>13.087145</td><td>77.589177</td><td>13.013447</td><td>77.561703</td><td>2</td><td>200.3</td><td>8.718</td><td>13.01</td><td>1.0</td><td>Yelahanka</td><td>Rajajinagar</td></tr><tr><td>2025-10-01 08:37:05</td><td>2025-10-01 08:44:57</td><td>12.956569</td><td>77.749813</td><td>12.975441</td><td>77.757532</td><td>2</td><td>95.69</td><td>2.259</td><td>7.87</td><td>1.0</td><td>Whitefield</td><td>Whitefield</td></tr><tr><td>2025-10-01 03:37:41</td><td>2025-10-01 03:52:45</td><td>12.967414</td><td>77.584438</td><td>12.8948</td><td>77.55798</td><td>1</td><td>201.14</td><td>8.568</td><td>15.07</td><td>1.0</td><td>MG_Road</td><td>Bannerghatta</td></tr></tbody></table></div>

# %%
df = bronze_df.dropDuplicates()

# Drop rows with missing essential values
df = df.dropna(subset=[
    "pickup_datetime",
    "dropoff_datetime",
    "pickup_latitude",
    "pickup_longitude",
    "dropoff_latitude",
    "dropoff_longitude",
    "fare_amount"
])

print("After cleaning:", df.count())
# Out:
# After cleaning: 10000

# %%
df = df.withColumn(
    "duration_min",
    (F.col("dropoff_datetime").cast("long") -
     F.col("pickup_datetime").cast("long")) / 60
)

df = df.filter(F.col("duration_min") > 0)

# %%
from pyspark.sql import functions as F

df = df.withColumn("pickup_latitude", F.col("pickup_latitude").cast("double")) \
       .withColumn("pickup_longitude", F.col("pickup_longitude").cast("double")) \
       .withColumn("dropoff_latitude", F.col("dropoff_latitude").cast("double")) \
       .withColumn("dropoff_longitude", F.col("dropoff_longitude").cast("double"))

# %%
df = df.filter(
    F.col("pickup_latitude").isNotNull() &
    F.col("pickup_longitude").isNotNull() &
    F.col("dropoff_latitude").isNotNull() &
    F.col("dropoff_longitude").isNotNull()
)

# %%
df = df.withColumn("pickup_latitude", F.col("pickup_latitude").cast("double")) \
       .withColumn("pickup_longitude", F.col("pickup_longitude").cast("double")) \
       .withColumn("dropoff_latitude", F.col("dropoff_latitude").cast("double")) \
       .withColumn("dropoff_longitude", F.col("dropoff_longitude").cast("double"))

df = df.filter(
    F.col("pickup_latitude").isNotNull() &
    F.col("pickup_longitude").isNotNull() &
    F.col("dropoff_latitude").isNotNull() &
    F.col("dropoff_longitude").isNotNull()
)

print("After lat/long cleaning:", df.count())
# Out:
# After lat/long cleaning: 0

# %%
df = df.withColumn(
    "distance_km",
    2 * 6371 * F.asin(
        F.sqrt(
            F.pow(
                F.sin((F.radians(F.col("dropoff_latitude")) -
                       F.radians(F.col("pickup_latitude"))) / 2), 2
            )
            +
            F.cos(F.radians(F.col("pickup_latitude"))) *
            F.cos(F.radians(F.col("dropoff_latitude"))) *
            F.pow(
                F.sin((F.radians(F.col("dropoff_longitude")) -
                       F.radians(F.col("pickup_longitude"))) / 2), 2
            )
        )
    )
)

# %%
df.select(
    "pickup_latitude",
    "pickup_longitude",
    "dropoff_latitude",
    "dropoff_longitude",
    "distance_km"
).show(5, truncate=False)
# Out:
# +---------------+----------------+----------------+-----------------+-----------+
# |pickup_latitude|pickup_longitude|dropoff_latitude|dropoff_longitude|distance_km|
# +---------------+----------------+----------------+-----------------+-----------+
# +---------------+----------------+----------------+-----------------+-----------+

# %%
df = df.filter(F.col("distance_km") > 0)
print("After distance filter:", df.count())
# Out:
# After distance filter: 0
